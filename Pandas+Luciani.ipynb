# %%
import pandas as pd

# %%
df = pd.read_csv('Summer-Olympic-medals-1976-to-2008.csv', encoding ='latin')
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %% [markdown]
# Estableciendo la columna "Year" como index del DF

# %%
df.set_index('Year')
# Out:
#             City      Sport       Discipline           Event  \
# Year
# 1976.0  Montreal   Aquatics           Diving  3m springboard
# 1976.0  Montreal   Aquatics           Diving  3m springboard
# 1976.0  Montreal   Aquatics           Diving  3m springboard
# 1976.0  Montreal   Aquatics           Diving  3m springboard
# 1976.0  Montreal   Aquatics           Diving    10m platform
# ...          ...        ...              ...             ...
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       55 - 60kg
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       60 - 66kg
# 2008.0   Beijing  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                          Athlete Gender Country_Code        Country  \
# Year
# 1976.0           KÖHLER, Christa  Women          GDR   East Germany
# 1976.0       KOSENKOV, Aleksandr    Men          URS   Soviet Union
# ...

# %%
df[['Apellido', 'Nombre', 'X']] = df['Athlete'].str.split(',', expand = True)
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
del df['X']

# %%
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
del df['Athlete']

# %%
df
# Out:
#            City    Year      Sport       Discipline           Event Gender  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard  Women
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard    Men
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard    Men
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard    Men
# 4      Montreal  1976.0   Aquatics           Diving    10m platform  Women
# ...         ...     ...        ...              ...             ...    ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg    Men
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg    Men
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg    Men
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg    Men
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg    Men
#
#       Country_Code        Country Event_gender   Medal   Apellido  \
# ...

# %% [markdown]
# Separando el Apellido y el Nombre de los participantes en dos columnas distintas

# %%
df = df.reindex(columns=['City', 'Year', 'Sport', 'Discipline', 'Event','Apellido', 'Nombre', 'Gender', 'Country_Code', 'Country', 'Event_gender', 'Medal'])

# %%
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#         Apellido           Nombre Gender Country_Code        Country  \
# 0         KÖHLER          Christa  Women          GDR   East Germany
# ...

# %%
df.set_index('Year')
# Out:
#             City      Sport       Discipline           Event   Apellido  \
# Year
# 1976.0  Montreal   Aquatics           Diving  3m springboard     KÖHLER
# 1976.0  Montreal   Aquatics           Diving  3m springboard   KOSENKOV
# 1976.0  Montreal   Aquatics           Diving  3m springboard      BOGGS
# 1976.0  Montreal   Aquatics           Diving  3m springboard   CAGNOTTO
# 1976.0  Montreal   Aquatics           Diving    10m platform     WILSON
# ...          ...        ...              ...             ...        ...
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg     GUENOT
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg  KVIRKELIA
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       55 - 60kg    RAHIMOV
# 2008.0   Beijing  Wrestling  Wrestling Gre-R       60 - 66kg     GUENOT
# 2008.0   Beijing  Wrestling  Wrestling Gre-R      96 - 120kg      LOPEZ
#
#                  Nombre Gender Country_Code        Country Event_gender  \
# Year
# ...

# %% [markdown]
# Presentando la lista de paises de acuerdo a la cantidad de medallas ganadas.

# %%
df['Country'].value_counts()
# Out:
# United States    1081
# Soviet Union      695
# Australia         444
# Italy             395
# Germany           379
#                  ...
# Burundi             1
# Lebanon             1
# Cote d'Ivoire       1
# Djibouti            1
# Vietnam             1
# Name: Country, Length: 122, dtype: int64

# %% [markdown]
# Aplicando esta mascara al DF luego se puede realizar la sumatoria de hombres por año que ganaron medallas.

# %%
df_men = df['Gender'] == 'Men'
df = df[df_men]
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 5      Montreal  1976.0   Aquatics           Diving    10m platform
# 8      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#         Apellido           Nombre Gender Country_Code        Country  \
# 1       KOSENKOV        Aleksandr    Men          URS   Soviet Union
# ...

# %%
df[['Year', 'Gender']].value_counts()
# Out:
# Year    Gender
# 2000.0  Men       1126
# 2008.0  Men       1110
# 1992.0  Men       1105
# 2004.0  Men       1099
# 1996.0  Men       1082
# 1988.0  Men       1011
# 1984.0  Men        973
# 1980.0  Men        958
# 1976.0  Men        924
# dtype: int64
